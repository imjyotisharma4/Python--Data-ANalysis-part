# %%
# import pandas  -    installing pandas

import pandas as pd

# %%
import numpy as np

# %%
salary=pd.Series(
np.array([2000,12000,43000,45000,65000,66000]),
    index=np.arange(0,12,2)   
)
salary
# Out:
# 0      2000
# 2     12000
# 4     43000
# 6     45000
# 8     65000
# 10    66000
# dtype: int32

# %%
emp=pd.Series(
np.array([2000,12000,43000,45000,65000,66000]),
    index=['a1','b2','c3','d4','e5','f6']
)
emp
# Out:
# a1     2000
# b2    12000
# c3    43000
# d4    45000
# e5    65000
# f6    66000
# dtype: int32

# %%
# dictionary

prod={'Dairy':23000,'Soft Drinks':45000,'Fruits & Vegetables':47000}
product=pd.Series(prod)
product
# Out:
# Dairy                  23000
# Soft Drinks            45000
# Fruits & Vegetables    47000
# dtype: int64

# %%
# create a dictionary

classes_dict={"X":["Maths","Science","English"],
             "Y":["Maths","Science"],
             "Z":"Science"}
# convert the dictionary in series
classes_series=pd.Series(classes_dict)

# print the series
classes_series
# Out:
# X    [Maths, Science, English]
# Y             [Maths, Science]
# Z                      Science
# dtype: object

# %%
import pandas as pd

# %%
# create a dictionary

classes_dict={"X":["Maths","Science","English"],
             "Y":["Maths","Science"],
             "Z":"Science"}
# convert the dictionary in series
classes_series=pd.Series(classes_dict)

# display  series index
classes_series.index
# Out:
# Index(['X', 'Y', 'Z'], dtype='object')

# %%
classes_series.index
# Out:
# Index(['X', 'Y', 'Z'], dtype='object')

# %%
classes_series['X']
# Out:
# ['Maths', 'Science', 'English']

# %%
classes_series['Y']
# Out:
# ['Maths', 'Science']

# %%
classes_series['Z']
# Out:
# 'Science'

# %%
import numpy as np

# %%
student_series=pd.Series(np.array([450,125,313,414,215,116]),
index=['Sophia','Emma','Mia','William','lily','Grace'])
    
student_series[student_series>300]
# Out:
# Sophia     450
# Mia        313
# William    414
# dtype: int32

# %%
mrp_series=pd.Series([12,15,17])
sales_series=pd.Series([23,43,34])

# multiply both the series
total_amt=mrp_series.multiply(sales_series)
print(total_amt)
# Out:
# 0    276
# 1    645
# 2    578
# dtype: int64

# %%
# create two arrays
eng_array=np.array([67,82,93])
eng_series=pd.Series(eng_array)

maths_array=np.array([91,72])
maths_series=pd.Series(maths_array)

total_m=eng_series+maths_series
total_m
# Out:
# 0    158.0
# 1    154.0
# 2      NaN
# dtype: float64

# %%
score=np.array([121,2121,153,214,115,116,237,118,119,120])
score=pd.Series(score)
score.rank()                   #ranking to the index
# Out:
# 0     6.0
# 1    10.0
# 2     7.0
# 3     8.0
# 4     1.0
# 5     2.0
# 6     9.0
# 7     3.0
# 8     4.0
# 9     5.0
# dtype: float64

# %%
# sort values
sales_series=pd.Series([2223,3445,np.nan,3411,6223,8334,2155,np.nan,3314,3210])

# sorting the index
sales_series.sort_values(ascending=True,na_position='first')
# Out:
# 2       NaN
# 7       NaN
# 6    2155.0
# 0    2223.0
# 9    3210.0
# 8    3314.0
# 3    3411.0
# 1    3445.0
# 4    6223.0
# 5    8334.0
# dtype: float64

# %%
# sort values
sales_series=pd.Series([2223,3445,np.nan,3411,6223,8334,2155,np.nan,3314,3210])

# sorting the index
sales_series.sort_values(ascending=True,na_position='last')
# Out:
# 6    2155.0
# 0    2223.0
# 9    3210.0
# 8    3314.0
# 3    3411.0
# 1    3445.0
# 4    6223.0
# 5    8334.0
# 2       NaN
# 7       NaN
# dtype: float64

# %%
height_series=pd.Series([4.4,np.nan,5.3,3.9,np.nan,5.3,5.4])
height_series.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# dtype: bool

# %%
height_series=pd.Series([4.4,np.nan,5.3,3.9,np.nan,5.3,5.4])
height_series.notnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# 6     True
# dtype: bool

# %%
# concatenation of panda series

# %%
import numpy as np

# %%
import pandas as pd

# %%
# create two series using linspace
# 'Start' returns the starting value of the sequence
# 'stop' returns the end point of the sequence
# 'num' returns the number of samples

class1=np.linspace(start=0,stop=20,num=11)
class2=np.linspace(start=1,stop=21,num=11)

# pd.Series returns the series of the passed data
class1_series=pd.Series(data=class1)
class2_series=pd.Series(data=class2)

pd.concat([class1_series,class2_series],ignore_index=True)          #used to add multiple values
# Out:
# 0      0.0
# 1      2.0
# 2      4.0
# 3      6.0
# 4      8.0
# 5     10.0
# 6     12.0
# 7     14.0
# 8     16.0
# 9     18.0
# 10    20.0
# 11     1.0
# 12     3.0
# 13     5.0
# 14     7.0
# 15     9.0
# 16    11.0
# 17    13.0
# 18    15.0
# 19    17.0
# 20    19.0
# 21    21.0
# dtype: float64

# %%
#  create two series using linspace
# 'Start' returns the starting value of the sequence
# 'stop' returns the end point of the sequence
# 'num' returns the number of samples

import numpy as np
import pandas as pd
class1=np.array([67,82,93])
class2=np.array([67,82,93])


# pd.Series returns the series of the passed data
class1_series=pd.Series(data=class1)
class2_series=pd.Series(data=class2)

class1_series.append(class2_series)                  # using append function to add two series values
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18600\3525117568.py:16: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   class1_series.append(class2_series)
# 0    67
# 1    82
# 2    93
# 0    67
# 1    82
# 2    93
# dtype: int32

# %% [markdown]
# # pandas -Dayanand sir

# %%
import pandas as pd
import numpy as np

# %%
arr1=np.random.randint(20,40,10)

# %%
print(arr1)
# Out:
# [31 36 20 38 25 25 24 33 28 31]

# %% [markdown]
# # series-pandas series object can be created using pd.Series()

# %%
mySer=pd.Series(arr1)

# %%
mySer
# Out:
# 0    26
# 1    22
# 2    26
# 3    37
# 4    28
# 5    37
# 6    34
# 7    22
# 8    39
# 9    24
# dtype: int32

# %%
type(mySer)
# Out:
# pandas.core.series.Series

# %%
dir(mySer)                     #
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
myList=[12,45,67,89,90]

# %%
mySer1=pd.Series(myList)
mySer1
# Out:
# 0    12
# 1    45
# 2    67
# 3    89
# 4    90
# dtype: int64

# %%
myTuple=(12,45,"Apple","Banana",89)
mySer2=pd.Series(myTuple)
mySer2
# Out:
# 0        12
# 1        45
# 2     Apple
# 3    Banana
# 4        89
# dtype: object

# %%
# Dictionary

myDic={'Name':'Mayank','Salary':50000,'Age':25}

# %%
mySer3=pd.Series(myDic)
mySer3
# Out:
# Name      Mayank
# Salary     50000
# Age           25
# dtype: object

# %%
mySet={12,13,18,11,12,11,15} 
mySet
# Out:
# {11, 12, 13, 15, 18}

# %%
mySer4=pd.Series(mySer3)                       #We cannot create series object using set as set is un-ordered 
mySer4
# Out:
# Name      Mayank
# Salary     50000
# Age           25
# dtype: object

# %%
mySer1
# Out:
# 0    12
# 1    45
# 2    67
# 3    89
# 4    90
# dtype: int64

# %%
mySer3=pd.Series([12,16,18,19],index=['a','b','c','d'])
mySer3
# Out:
# a    12
# b    16
# c    18
# d    19
# dtype: int64

# %%
mySer5=pd.Series(myList,index=['101','102','103','104','105'])
mySer5
# Out:
# 101    12
# 102    45
# 103    67
# 104    89
# 105    90
# dtype: int64

# %%
mySer5.add_prefix(prefix='std')
# Out:
# std101    12
# std102    45
# std103    67
# std104    89
# std105    90
# dtype: int64

# %%
mySer5.add_suffix(suffix='Roll no')
# Out:
# 101Roll no    12
# 102Roll no    45
# 103Roll no    67
# 104Roll no    89
# 105Roll no    90
# dtype: int64

# %%
# 11,14,15____,16,17      - List containing missing values

myList=[11,14,15,None,16,19,None]
mySer4=pd.Series(myList)
mySer4              #NaN - Not a number
# Out:
# 0    11.0
# 1    14.0
# 2    15.0
# 3     NaN
# 4    16.0
# 5    19.0
# 6     NaN
# dtype: float64

# %%
# dtype- data type
mySer4.dtype              #high dimension - float.We don't know how we will replace with integer/float.
# Out:
# dtype('float64')

# %%
# isna() - It returns missing value info in bool where we have missing values it returns  'True' otehrwise 'False'
# isnull()
# gives 'True' at null values

print(mySer4.isna())
print(mySer4.isnull())
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# dtype: bool
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
mySer4.isna().sum()            #gives count of missing values
# Out:
# 2

# %%
mySer4.isna().any()                  #gives missing value if any
# Out:
# True

# %%
mySer4.dropna()
# Out:
# 0    11.0
# 1    14.0
# 2    15.0
# 4    16.0
# 5    19.0
# dtype: float64

# %%
mySer4.fillna(15)                  #missing values filled with - 15
# Out:
# 0    11.0
# 1    14.0
# 2    15.0
# 3    15.0
# 4    16.0
# 5    19.0
# 6    15.0
# dtype: float64

# %%
# Numerical-mean , median    #Categorical-mode..................We used to fill null values

# %%
import numpy as np
tempMean=np.mean(mySer4)
tempMean
# Out:
# 15.0

# %%
mySer4.fillna(tempMean)
# Out:
# 0    11.0
# 1    14.0
# 2    15.0
# 3    15.0
# 4    16.0
# 5    19.0
# 6    15.0
# dtype: float64

# %%
import numpy as np
tempMedian=np.median(mySer4)
tempMedian
# Out:
# nan

# %%
import numpy as np
tempMedian=np.nanmedian(mySer4)
tempMedian
# Out:
# 15.0

# %%
tempMean=mySer4.mean()
tempMean
# Out:
# 15.0

# %%
tempMedian=mySer4.median()
tempMedian
# Out:
# 15.0

# %%
mySer4.fillna(mySer4.median())
# Out:
# 0    11.0
# 1    14.0
# 2    15.0
# 3    15.0
# 4    16.0
# 5    19.0
# 6    15.0
# dtype: float64

# %%
mySer4.dtype
# Out:
# dtype('float64')

# %%
# as type
mySer5.astype('int32')
# Out:
# 101    12
# 102    45
# 103    67
# 104    89
# 105    90
# dtype: int32

# %%
def myFun(df):
    return df*10

# %%
#At Columns , on elements - apply
mySer3.apply(myFun)
# Out:
# a    120
# b    160
# c    180
# d    190
# dtype: int64

# %%
mySer6=pd.Series([12,13,14,115,12,13,16,17,12,13,15])
mySer6
# Out:
# 0      12
# 1      13
# 2      14
# 3     115
# 4      12
# 5      13
# 6      16
# 7      17
# 8      12
# 9      13
# 10     15
# dtype: int64

# %%
mySer6.drop_duplicates()
# Out:
# 0      12
# 1      13
# 2      14
# 3     115
# 6      16
# 7      17
# 10     15
# dtype: int64

# %%
import pandas as pd
import numpy as np
myDic={'emp_id':[101,102,103,104,105],
'emp_name':['tej','palak','osman','anuj','sachin'],
'gender':['m','f','m','f','m'],
'salary':[10000,20000,30000,40000,50000]}

# %%
myDic
# Out:
# {'emp_id': [101, 102, 103, 104, 105],
#  'emp_name': ['tej', 'palak', 'osman', 'anuj', 'sachin'],
#  'gender': ['m', 'f', 'm', 'f', 'm'],
#  'salary': [10000, 20000, 30000, 40000, 50000]}

# %%
#DAtaFrame
# pd.DataFrame().We can create data frame using DataFrame method
myDic1=pd.DataFrame(myDic)
myDic1
# Out:
#    emp_id emp_name gender  salary
# 0     101      tej      m   10000
# 1     102    palak      f   20000
# 2     103    osman      m   30000
# 3     104     anuj      f   40000
# 4     105   sachin      m   50000

# %%
myList=[[111,'Jyoti','Dsa'],
       [112,'Rashi','BA'],
       [113, 'Bharat','Ai',]]

# %%
myList
# Out:
# [[111, 'Jyoti', 'Dsa'], [112, 'Rashi', 'BA'], [113, 'Bharat', 'Ai']]

# %%
myDf1=pd.DataFrame(myList,columns=['Std_Roll','Name','Course'])
myDf1
# Out:
#    Std_Roll    Name Course
# 0       111   Jyoti    Dsa
# 1       112   Rashi     BA
# 2       113  Bharat     Ai

# %%
ser1=pd.Series(np.random.randint(20,60,5))
ser2=pd.Series(np.random.randint(35000,55000,5))
ser2
# Out:
# 0    47826
# 1    37556
# 2    38341
# 3    47093
# 4    41567
# dtype: int32

# %%
#load the file
# read_csv()  Method by which we load/ read our csv file

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\hp\\Downloads\\Data_File.csv")
df                                       #use \\ or /
# Out:
#     Variable_A  Variable_B  Variable_C  Variable_D Variable_E
# 0          6.0         148          72          35          A
# 1          1.0          85          66          29          A
# 2          8.0         183          64           0          B
# 3          1.0          89          66          23          B
# 4          0.0         137          40          35          C
# 5          5.0         116          74           0          A
# 6          3.0          78          50          32          C
# 7         10.0         115           0           0          A
# 8          2.0         197          70          45          C
# 9          NaN         125          96           0          C
# 10         4.0         110          92           0          B
# 11        10.0         168          74           0          A
# 12         NaN         139          80           0          A
# 13         1.0         189          60          23          C

# %%
df.head()                   #displays first five rows
# Out:
#    Variable_A  Variable_B  Variable_C  Variable_D Variable_E
# 0         6.0         148          72          35          A
# 1         1.0          85          66          29          A
# 2         8.0         183          64           0          B
# 3         1.0          89          66          23          B
# 4         0.0         137          40          35          C

# %%
df.tail()                          #displays first five rows
# Out:
#     Variable_A  Variable_B  Variable_C  Variable_D Variable_E
# 9          NaN         125          96           0          C
# 10         4.0         110          92           0          B
# 11        10.0         168          74           0          A
# 12         NaN         139          80           0          A
# 13         1.0         189          60          23          C

# %%
df.head(8)                         #8 top rows
# Out:
#    Variable_A  Variable_B  Variable_C  Variable_D Variable_E
# 0         6.0         148          72          35          A
# 1         1.0          85          66          29          A
# 2         8.0         183          64           0          B
# 3         1.0          89          66          23          B
# 4         0.0         137          40          35          C
# 5         5.0         116          74           0          A
# 6         3.0          78          50          32          C
# 7        10.0         115           0           0          A

# %%
df.columns
# Out:
# Index(['Variable_A', 'Variable_B', 'Variable_C', 'Variable_D', 'Variable_E'], dtype='object')

# %%
#Shape - Displays no of rows & columns

# %%
df.shape
# Out:
# (14, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Variable_A  12 non-null     float64
#  1   Variable_B  14 non-null     int64
#  2   Variable_C  14 non-null     int64
#  3   Variable_D  14 non-null     int64
#  4   Variable_E  14 non-null     object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 688.0+ bytes

# %%
#describe() - Statistical summary of data
df.describe()
# Out:
#        Variable_A  Variable_B  Variable_C  Variable_D
# count   12.000000   14.000000   14.000000   14.000000
# mean     4.250000  134.214286   64.571429   15.857143
# std      3.570714   38.912483   23.617836   17.270950
# min      0.000000   78.000000    0.000000    0.000000
# 25%      1.000000  111.250000   61.000000    0.000000
# 50%      3.500000  131.000000   68.000000   11.500000
# 75%      6.500000  163.000000   74.000000   31.250000
# max     10.000000  197.000000   96.000000   45.000000

# %%
df.describe(include='all')                    # Gives all categorical/continuous data
# Out:
#         Variable_A  Variable_B  Variable_C  Variable_D Variable_E
# count    12.000000   14.000000   14.000000   14.000000         14
# unique         NaN         NaN         NaN         NaN          3
# top            NaN         NaN         NaN         NaN          A
# freq           NaN         NaN         NaN         NaN          6
# mean      4.250000  134.214286   64.571429   15.857143        NaN
# std       3.570714   38.912483   23.617836   17.270950        NaN
# min       0.000000   78.000000    0.000000    0.000000        NaN
# 25%       1.000000  111.250000   61.000000    0.000000        NaN
# 50%       3.500000  131.000000   68.000000   11.500000        NaN
# 75%       6.500000  163.000000   74.000000   31.250000        NaN
# max      10.000000  197.000000   96.000000   45.000000        NaN

# %%
#isna() / isnull()
df.isna().sum()
# Out:
# Variable_A    2
# Variable_B    0
# Variable_C    0
# Variable_D    0
# Variable_E    0
# dtype: int64

# %%
#Fill missing values
df['Variable_A'].fillna(10)
# Out:
# 0      6.0
# 1      1.0
# 2      8.0
# 3      1.0
# 4      0.0
# 5      5.0
# 6      3.0
# 7     10.0
# 8      2.0
# 9     10.0
# 10     4.0
# 11    10.0
# 12    10.0
# 13     1.0
# Name: Variable_A, dtype: float64

# %%
df["Variable_A"].fillna(df["Variable_A"].mean())
# Out:
# 0      6.00
# 1      1.00
# 2      8.00
# 3      1.00
# 4      0.00
# 5      5.00
# 6      3.00
# 7     10.00
# 8      2.00
# 9      4.25
# 10     4.00
# 11    10.00
# 12     4.25
# 13     1.00
# Name: Variable_A, dtype: float64

# %%
#alternate
tempMean=df["Variable_A"].mean()
tempMean=df["Variable_A"].fillna(tempMean)                #variable not define i.e why still showing the null values
df
# Out:
#     Variable_A  Variable_B  Variable_C  Variable_D Variable_E
# 0          6.0         148          72          35          A
# 1          1.0          85          66          29          A
# 2          8.0         183          64           0          B
# 3          1.0          89          66          23          B
# 4          0.0         137          40          35          C
# 5          5.0         116          74           0          A
# 6          3.0          78          50          32          C
# 7         10.0         115           0           0          A
# 8          2.0         197          70          45          C
# 9          NaN         125          96           0          C
# 10         4.0         110          92           0          B
# 11        10.0         168          74           0          A
# 12         NaN         139          80           0          A
# 13         1.0         189          60          23          C

# %%
#alternate
tempMean=df["Variable_A"].mean()
df["Variable_A"]=df["Variable_A"].fillna(tempMean)                 #We assign the same variable for storing the changes
df
# Out:
#     Variable_A  Variable_B  Variable_C  Variable_D Variable_E
# 0         6.00         148          72          35          A
# 1         1.00          85          66          29          A
# 2         8.00         183          64           0          B
# 3         1.00          89          66          23          B
# 4         0.00         137          40          35          C
# 5         5.00         116          74           0          A
# 6         3.00          78          50          32          C
# 7        10.00         115           0           0          A
# 8         2.00         197          70          45          C
# 9         4.25         125          96           0          C
# 10        4.00         110          92           0          B
# 11       10.00         168          74           0          A
# 12        4.25         139          80           0          A
# 13        1.00         189          60          23          C

# %%
# subsetting/extracting #rows
df[0:5]   # 0 to 4th row
df[2:7]   # 2 to 6
# Out:
#    Variable_A  Variable_B  Variable_C  Variable_D Variable_E
# 2         8.0         183          64           0          B
# 3         1.0          89          66          23          B
# 4         0.0         137          40          35          C
# 5         5.0         116          74           0          A
# 6         3.0          78          50          32          C

# %%
# Column 
df["Variable_A"]
# Out:
# 0      6.00
# 1      1.00
# 2      8.00
# 3      1.00
# 4      0.00
# 5      5.00
# 6      3.00
# 7     10.00
# 8      2.00
# 9      4.25
# 10     4.00
# 11    10.00
# 12     4.25
# 13     1.00
# Name: Variable_A, dtype: float64

# %%
df[["Variable_C","Variable_A","Variable_B"]]       #df[]                                  # create list and access elements
# Out:
#     Variable_C  Variable_A  Variable_B
# 0           72        6.00         148
# 1           66        1.00          85
# 2           64        8.00         183
# 3           66        1.00          89
# 4           40        0.00         137
# 5           74        5.00         116
# 6           50        3.00          78
# 7            0       10.00         115
# 8           70        2.00         197
# 9           96        4.25         125
# 10          92        4.00         110
# 11          74       10.00         168
# 12          80        4.25         139
# 13          60        1.00         189

# %%
# needs both rows and columns on index subsetting (R,C format)
# index based subsetting(iloc)

df.iloc[0:5,1:3]          #0 to 4 rows and 1 to 2 columns
# Out:
#    Variable_B  Variable_C
# 0         148          72
# 1          85          66
# 2         183          64
# 3          89          66
# 4         137          40

# %%
df.iloc[0:5,:]         #gives rows only
# Out:
#    Variable_A  Variable_B  Variable_C  Variable_D Variable_E
# 0         6.0         148          72          35          A
# 1         1.0          85          66          29          A
# 2         8.0         183          64           0          B
# 3         1.0          89          66          23          B
# 4         0.0         137          40          35          C

# %%
df.iloc[,1:3]            #error
# Out:
#   Input In [103]
#     df.iloc[,1:3]            #error
#             ^
# SyntaxError: invalid syntax

# %%
df.iloc[:,1:3]
# Out:
#     Variable_B  Variable_C
# 0          148          72
# 1           85          66
# 2          183          64
# 3           89          66
# 4          137          40
# 5          116          74
# 6           78          50
# 7          115           0
# 8          197          70
# 9          125          96
# 10         110          92
# 11         168          74
# 12         139          80
# 13         189          60

# %%
#Value based subsetting
df.loc[1:5,"Variable_A"]                           #in loc, we mention Variables also but in iloc , we will use numericals only
# Out:
# 1    1.0
# 2    8.0
# 3    1.0
# 4    0.0
# 5    5.0
# Name: Variable_A, dtype: float64

# %%
df.iloc[1:5,"Variable_A"]       #show error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:769, in _LocationIndexer._validate_tuple_indexer(self, key)
#     768 try:
# --> 769     self._validate_key(k, i)
#     770 except ValueError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1378, in _iLocIndexer._validate_key(self, key, axis)
#    1377 else:
# -> 1378     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [106], in <cell line: 1>()
# ----> 1 df.iloc[1:5,"Variable_A"]
#
# ...

# %%
df.loc[1:5,["Variable_A","Variable_B"]]           # we need container
# Out:
#    Variable_A  Variable_B
# 1         1.0          85
# 2         8.0         183
# 3         1.0          89
# 4         0.0         137
# 5         5.0         116

# %%
df["Variable_A"]>2               #Gives boolean - conditional operator
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4     False
# 5      True
# 6      True
# 7      True
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13    False
# Name: Variable_A, dtype: bool

# %%
df[df["Variable_A"]>2 ]                                     #dataframe display the value that will be true
# Out:
#     Variable_A  Variable_B  Variable_C  Variable_D Variable_E
# 0         6.00         148          72          35          A
# 2         8.00         183          64           0          B
# 5         5.00         116          74           0          A
# 6         3.00          78          50          32          C
# 7        10.00         115           0           0          A
# 9         4.25         125          96           0          C
# 10        4.00         110          92           0          B
# 11       10.00         168          74           0          A
# 12        4.25         139          80           0          A

# %%
df["Variable_A"][df["Variable_A"]>2 ]                #dataframe display the value that will be true
# Out:
# 0      6.00
# 2      8.00
# 5      5.00
# 6      3.00
# 7     10.00
# 9      4.25
# 10     4.00
# 11    10.00
# 12     4.25
# Name: Variable_A, dtype: float64

# %%
df.columns
# Out:
# Index(['Variable_A', 'Variable_B', 'Variable_C', 'Variable_D', 'Variable_E'], dtype='object')

# %%
dff=df.rename(columns={"Variable_A":"Variable_A_new","Variable_B":"Variable_B_new","Variable_C":"Variable_C_new",
                   "Variable_D":"Variable_D_new","Variable_E":"Variable_E_new","Variable_F":"Variable_F_new"})   #To rename
dff
# Out:
#     Variable_A_new  Variable_B_new  Variable_C_new  Variable_D_new  \
# 0             6.00             148              72              35
# 1             1.00              85              66              29
# 2             8.00             183              64               0
# 3             1.00              89              66              23
# 4             0.00             137              40              35
# 5             5.00             116              74               0
# 6             3.00              78              50              32
# 7            10.00             115               0               0
# 8             2.00             197              70              45
# 9             4.25             125              96               0
# 10            4.00             110              92               0
# 11           10.00             168              74               0
# 12            4.25             139              80               0
# ...

# %%
# Creating new columns
# dataframe["New_Column_Name"]= New
dff["Variable_F_new"]=dff["Variable_A_new"]*10
dff["Variable_F_new"]
# Out:
# 0      60.0
# 1      10.0
# 2      80.0
# 3      10.0
# 4       0.0
# 5      50.0
# 6      30.0
# 7     100.0
# 8      20.0
# 9      42.5
# 10     40.0
# 11    100.0
# 12     42.5
# 13     10.0
# Name: Variable_F_new, dtype: float64

# %%
dff.drop (["Variable_A_new"], axis=1)
dff
# Out:
#     Variable_A_new  Variable_C_new Variable_E_new  Variable_F_New  \
# 0             6.00              72              A            60.0
# 1             1.00              66              A            10.0
# 2             8.00              64              B            80.0
# 3             1.00              66              B            10.0
# 4             0.00              40              C             0.0
# 5             5.00              74              A            50.0
# 6             3.00              50              C            30.0
# 7            10.00               0              A           100.0
# 8             2.00              70              C            20.0
# 9             4.25              96              C            42.5
# 10            4.00              92              B            40.0
# 11           10.00              74              A           100.0
# 12            4.25              80              A            42.5
# ...

# %%
# delete columns
# drop()
# axis=0 (rows) & axis=1(columns)
dff.drop (["Variable_B_new"], axis=1, inplace=True)
# inplace= True (It assigns the change in the original variable)
dff
# Out:
#     Variable_A_new  Variable_C_new Variable_E_new  Variable_F_New  \
# 0             6.00              72              A            60.0
# 1             1.00              66              A            10.0
# 2             8.00              64              B            80.0
# 3             1.00              66              B            10.0
# 4             0.00              40              C             0.0
# 5             5.00              74              A            50.0
# 6             3.00              50              C            30.0
# 7            10.00               0              A           100.0
# 8             2.00              70              C            20.0
# 9             4.25              96              C            42.5
# 10            4.00              92              B            40.0
# 11           10.00              74              A           100.0
# 12            4.25              80              A            42.5
# ...

# %%
dff.drop(11, axis=0)
# Out:
#     Variable_A_new  Variable_C_new Variable_E_new  Variable_F_New  \
# 0             6.00              72              A            60.0
# 1             1.00              66              A            10.0
# 2             8.00              64              B            80.0
# 3             1.00              66              B            10.0
# 4             0.00              40              C             0.0
# 5             5.00              74              A            50.0
# 6             3.00              50              C            30.0
# 7            10.00               0              A           100.0
# 8             2.00              70              C            20.0
# 9             4.25              96              C            42.5
# 10            4.00              92              B            40.0
# 12            4.25              80              A            42.5
# 13            1.00              60              C            10.0
#
#     Variable_F_new
# 0             60.0
# ...

# %%
df.drop([1,3], axis=0)
# Out:
#     Variable_A  Variable_B  Variable_C  Variable_D Variable_E
# 0         6.00         148          72          35          A
# 2         8.00         183          64           0          B
# 4         0.00         137          40          35          C
# 5         5.00         116          74           0          A
# 6         3.00          78          50          32          C
# 7        10.00         115           0           0          A
# 8         2.00         197          70          45          C
# 9         4.25         125          96           0          C
# 10        4.00         110          92           0          B
# 11       10.00         168          74           0          A
# 12        4.25         139          80           0          A
# 13        1.00         189          60          23          C

# %%
# copy()
df_Copy=df.copy()
df_Copy
# Out:
#     Variable_A  Variable_B  Variable_C  Variable_D Variable_E
# 0         6.00         148          72          35          A
# 1         1.00          85          66          29          A
# 2         8.00         183          64           0          B
# 3         1.00          89          66          23          B
# 4         0.00         137          40          35          C
# 5         5.00         116          74           0          A
# 6         3.00          78          50          32          C
# 7        10.00         115           0           0          A
# 8         2.00         197          70          45          C
# 9         4.25         125          96           0          C
# 10        4.00         110          92           0          B
# 11       10.00         168          74           0          A
# 12        4.25         139          80           0          A
# 13        1.00         189          60          23          C

# %%
# concat()
# axis=0 (rowwise), axis=1 (columnwise)
rowWiseConcat=pd.concat([dff,df_Copy], axis=0) # one below another
columnWiseConcat=pd.concat([dff, df_Copy], axis=1) # one beside another

# %%
print("Shape of df & df_Copy", df.shape, df_Copy.shape)
print(" Shape of rowWiseConcat ",rowWiseConcat.shape)
print("Shape of columnWiseConcat", columnWiseConcat. shape)
# Out:
# Shape of df & df_Copy (14, 5) (14, 5)
#  Shape of rowWiseConcat  (28, 10)
# Shape of columnWiseConcat (14, 10)

# %%
rowWiseConcat
# Out:
#     Variable_A_new  Variable_C_new Variable_E_new  Variable_F_New  \
# 0             6.00            72.0              A            60.0
# 1             1.00            66.0              A            10.0
# 2             8.00            64.0              B            80.0
# 3             1.00            66.0              B            10.0
# 4             0.00            40.0              C             0.0
# 5             5.00            74.0              A            50.0
# 6             3.00            50.0              C            30.0
# 7            10.00             0.0              A           100.0
# 8             2.00            70.0              C            20.0
# 9             4.25            96.0              C            42.5
# 10            4.00            92.0              B            40.0
# 11           10.00            74.0              A           100.0
# 12            4.25            80.0              A            42.5
# ...

# %%
columnWiseConcat
# Out:
#     Variable_A_new  Variable_C_new Variable_E_new  Variable_F_New  \
# 0             6.00              72              A            60.0
# 1             1.00              66              A            10.0
# 2             8.00              64              B            80.0
# 3             1.00              66              B            10.0
# 4             0.00              40              C             0.0
# 5             5.00              74              A            50.0
# 6             3.00              50              C            30.0
# 7            10.00               0              A           100.0
# 8             2.00              70              C            20.0
# 9             4.25              96              C            42.5
# 10            4.00              92              B            40.0
# 11           10.00              74              A           100.0
# 12            4.25              80              A            42.5
# ...

# %%
# group by
dff.groupby("Variable_E_new")

# %%
dff.groupby("Variable_E_new") .count()
# Out:
#                 Variable_A_new  Variable_C_new  Variable_F_New  Variable_F_new
# Variable_E_new
# A                            6               6               6               6
# B                            3               3               3               3
# C                            5               5               5               5

# %%
#       Categorical Variable       Continuous Columns    aggregate function
dff.groupby("Variable_E_new")["Variable_A_new"]. mean()
# Out:
# Variable_E_new
# A    6.041667
# B    4.333333
# C    2.050000
# Name: Variable_A_new, dtype: float64

# %%
dff["Variable_E_new"]. value_counts()
# Out:
# A    6
# C    5
# B    3
# Name: Variable_E_new, dtype: int64

# %%
dff["Variable_E_new"]. count()
# Out:
# 14

# %%
rowise1=pd.concat([dff,dF1],axis=1)
rowise1=pd.concat([dff,df_Copy],axis=0)
colwise1=pd.concat([dff,dF1],axis=1)
colwise1=pd.concat([dff,df_Copy],axis=0)
print(rowise1.shape,rowise2.shape,colwise1.shape,colwise2.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [113], in <cell line: 1>()
# ----> 1 rowise1=pd.concat([dff,dF1],axis=1)
#       2 rowise1=pd.concat([dff,df_Copy],axis=0)
#       3 colwise1=pd.concat([dff,dF1],axis=1)
#
# NameError: name 'dF1' is not defined

# %% [markdown]
# # pandas

# %%
import pandas as pd

# %%
import numpy as np

# %%
print(pd.__version__)
# Out:
# 1.4.2

# %%
order=[1,2,3,4,5,6]
arr=["Ankit","Radhika","Anuj","Prateek","Anshuman","Geeta"]
s=pd.Series(arr,index=order)
s
# Out:
# 1       Ankit
# 2     Radhika
# 3        Anuj
# 4     Prateek
# 5    Anshuman
# 6       Geeta
# dtype: object

# %%
n=np.random.randn(5)                       # gives any 5 random values
index=['a','b','c','d','e']                         # index
s=pd.Series(n,index=index)                       #numbers,index
s
# Out:
# a    0.368325
# b   -0.707186
# c    1.169298
# d   -1.120824
# e    1.717480
# dtype: float64

# %%
s.drop('e')               #print all the index except the index containing value 'e'
# Out:
# a    0.416461
# b    1.132029
# c   -0.695752
# d    0.535782
# dtype: float64

# %%
dates=pd.date_range('today',periods=6)
dates
# Out:
# DatetimeIndex(['2022-10-14 22:41:15.530057', '2022-10-15 22:41:15.530057',
#                '2022-10-16 22:41:15.530057', '2022-10-17 22:41:15.530057',
#                '2022-10-18 22:41:15.530057', '2022-10-19 22:41:15.530057'],
#               dtype='datetime64[ns]', freq='D')

# %%
num_arr=np.random.randn(6,4)                  #random numbers
num_arr
# Out:
# array([[-0.9122555 , -0.42875333,  0.40375835, -1.43393721],
#        [ 0.62724217,  1.24145356,  0.21804872,  0.18266857],
#        [ 0.76254243, -0.36515005, -0.03312806,  0.8268512 ],
#        [ 0.99749403, -0.35106098,  0.33103188, -1.22228612],
#        [-1.33778267, -0.73693085, -0.26287853,  0.11757623],
#        [-0.17189227, -1.82171172, -0.92023108, -0.37729447]])

# %%
columns=['a','b','c','d']
df1=pd.DataFrame(num_arr,index=dates,columns=columns)
df1
# Out:
#                                    a         b         c         d
# 2022-10-14 22:41:15.530057 -0.912255 -0.428753  0.403758 -1.433937
# 2022-10-15 22:41:15.530057  0.627242  1.241454  0.218049  0.182669
# 2022-10-16 22:41:15.530057  0.762542 -0.365150 -0.033128  0.826851
# 2022-10-17 22:41:15.530057  0.997494 -0.351061  0.331032 -1.222286
# 2022-10-18 22:41:15.530057 -1.337783 -0.736931 -0.262879  0.117576
# 2022-10-19 22:41:15.530057 -0.171892 -1.821712 -0.920231 -0.377294

# %%
data={'animal':['cat','cat','snake','dog','dog','cat','snake','cat','dog','dog'],
      'age':[2.5,3,0.5,np.nan,5,2,4.5,np.nan,7,3],
      'visits':[1,3,2,3,2,3,1,1,2,1],
      'priority':['yes','yes','no','yes','no','no','no','yes','no','no']}
labels=['a','b','c','d','e','f','g','h','i','j']
df=pd.DataFrame(data,index=labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df.dtypes                           # see data types of array
# Out:
# animal       object
# age         float64
# visits        int64
# priority     object
# dtype: object

# %%
df.head(3)                           #show first 6 values
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
df.tail(3)                                       #show last 3 values
# Out:
#   animal  age  visits priority
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df.index                          #index only
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='object')

# %%
df.columns                            #columns
# Out:
# Index(['animal', 'age', 'visits', 'priority'], dtype='object')

# %%
df.values                  # values
# Out:
# array([['cat', 2.5, 1, 'yes'],
#        ['cat', 3.0, 3, 'yes'],
#        ['snake', 0.5, 2, 'no'],
#        ['dog', nan, 3, 'yes'],
#        ['dog', 5.0, 2, 'no'],
#        ['cat', 2.0, 3, 'no'],
#        ['snake', 4.5, 1, 'no'],
#        ['cat', nan, 1, 'yes'],
#        ['dog', 7.0, 2, 'no'],
#        ['dog', 3.0, 1, 'no']], dtype=object)

# %%
df.describe()               #statistical data of data frame
# Out:
#             age     visits
# count  8.000000  10.000000
# mean   3.437500   1.900000
# std    2.007797   0.875595
# min    0.500000   1.000000
# 25%    2.375000   1.000000
# 50%    3.000000   2.000000
# 75%    4.625000   2.750000
# max    7.000000   3.000000

# %% [markdown]
# # Manipulation

# %%
df.T                                                      #transpose
# Out:
#             a    b      c    d    e    f      g    h    i    j
# animal    cat  cat  snake  dog  dog  cat  snake  cat  dog  dog
# age       2.5  3.0    0.5  NaN  5.0  2.0    4.5  NaN  7.0  3.0
# visits      1    3      2    3    2    3      1    1    2    1
# priority  yes  yes     no  yes   no   no     no  yes   no   no

# %%
df.sort_values(by='age')                     # sorting by age
# Out:
#   animal  age  visits priority
# c  snake  0.5       2       no
# f    cat  2.0       3       no
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# j    dog  3.0       1       no
# g  snake  4.5       1       no
# e    dog  5.0       2       no
# i    dog  7.0       2       no
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
df.sort_values(by='age')[1:3]                #slicing df
# Out:
#   animal  age  visits priority
# f    cat  2.0       3       no
# a    cat  2.5       1      yes

# %%
# query df by tag

df[['age','visits']]           #show 'age','visits'
# Out:
#    age  visits
# a  2.5       1
# b  3.0       3
# c  0.5       2
# d  NaN       3
# e  5.0       2
# f  2.0       3
# g  4.5       1
# h  NaN       1
# i  7.0       2
# j  3.0       1

# %%
df.iloc[1:3]                  # query rows 2,3  -  location
# Out:
#   animal  age  visits priority
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
df1=df.copy                    #copy of df
df1()
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df.isnull()                      #gives null value
# Out:
#    animal    age  visits  priority
# a   False  False   False     False
# b   False  False   False     False
# c   False  False   False     False
# d   False   True   False     False
# e   False  False   False     False
# f   False  False   False     False
# g   False  False   False     False
# h   False   True   False     False
# i   False  False   False     False
# j   False  False   False     False

# %%
df.loc['f','age']=1.5                        #changes the value of 'f' age to 1.5 
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df.mean()                     #find mean
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19860\2489221929.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()                     #find mean
# age       3.4375
# visits    1.9000
# dtype: float64

# %%
df.sum()                 #combine the sum
# Out:
# animal      catcatsnakedogdogcatsnakecatdogdog
# age                                       27.5
# visits                                      19
# priority              yesyesnoyesnononoyesnono
# dtype: object

# %%
df1=df.copy()
df1.dropna(how='any')                      #drop null values
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# # file operations

# %%
import numpy as np

# %%
import pandas as pd

# %%
data=pd.read_csv('matches - matches.csv')

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()              #give top 5 values or we can write(10) for top 10 videos
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.tail()                #give last 5 values
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
data.shape                #give 636 rows and 18 columns                - here shape is an attribute but not a functin
# Out:
# (636, 18)

# %%
data.info ()              # provides preview of data- "object" is string here
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.describe()         #count of id,count of season
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
data['winner']                    #fetch data of winner colums with respect to index-      'single column fetch'
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
type(data['winner'])
# Out:
# pandas.core.series.Series

# %%
data[['team1','team2','winner']]              #fetch data of winner columns with respect to index  - 'Multiple column fetch'
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
type(data[['team1','team2','winner']]  )
# Out:
# pandas.core.frame.DataFrame

# %%
data[['team1','team2','winner']].shape
# Out:
# (636, 3)

# %%
data.iloc[2]                 #fetch the 1st row of DataFrame from each column
# Out:
# id                                                      3
# season                                               2017
# city                                               Rajkot
# date                                           2017-04-07
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                              0
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %%
data.iloc[1:3]              #DataFrame- fetch data from 1 & 2 row
# Out:
#    id  season    city        date           team1                   team2  \
# 1   2    2017    Pune  2017-04-06  Mumbai Indians  Rising Pune Supergiant
# 2   3    2017  Rajkot  2017-04-07   Gujarat Lions   Kolkata Knight Riders
#
#               toss_winner toss_decision  result  dl_applied  \
# 1  Rising Pune Supergiant         field  normal           0
# 2   Kolkata Knight Riders         field  normal           0
#
#                    winner  win_by_runs  win_by_wickets player_of_match  \
# 1  Rising Pune Supergiant            0               7       SPD Smith
# 2   Kolkata Knight Riders            0              10         CA Lynn
#
#                                      venue         umpire1    umpire2  umpire3
# 1  Maharashtra Cricket Association Stadium  A Nand Kishore     S Ravi      NaN
# 2   Saurashtra Cricket Association Stadium     Nitin Menon  CK Nandan      NaN

# %%
data.iloc[1:11:2]                  #skip alternate values
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
# 9          Mumbai Indians               Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# ...

# %%
data.iloc[[1,5,6]]                  #fetch data from 1,5 & 6 - fancy indexing t fetch values
# Out:
#    id  season       city        date                  team1  \
# 1   2    2017       Pune  2017-04-06         Mumbai Indians
# 5   6    2017  Hyderabad  2017-04-09          Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09  Kolkata Knight Riders
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
# 6          Mumbai Indians          Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 5           0     Sunrisers Hyderabad            0               9
# 6           0          Mumbai Indians            0               4
#
#   player_of_match                                      venue         umpire1  \
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
# ...

# %%
data.iloc[:,[4,5,10]]                     # ':'- all rows & 4,5,10th column
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
data['city']               #fetch 'city' from each index
# Out:
# 0      Hyderabad
# 1           Pune
# 2         Rajkot
# 3         Indore
# 4      Bangalore
#          ...
# 631       Raipur
# 632    Bangalore
# 633        Delhi
# 634        Delhi
# 635    Bangalore
# Name: city, Length: 636, dtype: object

# %%
data['city']=='Hyderabad'             #will give True or False values if the city is Hyderabad with index.
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: city, Length: 636, dtype: bool

# %%
mask=data['city']=='Hyderabad' 
data[mask]              #if given 'mask' only, it will return Bool values - Here extracting the data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 65    66    2008  Hyderabad  2008-04-22              Deccan Chargers
# 67    68    2008  Hyderabad  2008-04-24              Deccan Chargers
# 76    77    2008  Hyderabad  2008-05-01              Deccan Chargers
# 79    80    2008  Hyderabad  2008-05-25              Deccan Chargers
# 91    92    2008  Hyderabad  2008-05-11        Kolkata Knight Riders
# ...

# %%
data[mask].shape[0]                                             #Count the number of values
# Out:
# 49

# %%
# using function
def get_city_match_count(city):
    mask=data['city']=='Chennai'
    return data[mask].shape[0]
get_city_match_count('Chennai')                                      #no. of matches
# Out:
# 48

# %%
mask1=data['city']='Hyderabad'
mask2=data['date']>'2010-01-01'                             #Dates where matches played after 1/1/2010 
mask2
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 631    True
# 632    True
# 633    True
# 634    True
# 635    True
# Name: date, Length: 636, dtype: bool

# %%
mask2.shape[0]
# Out:
# 636

# %%
data['winner'].value_counts()                     -------------------                #series
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
mask=data[['team1','team2','winner']].value_counts()     --------------      #gives total value count
mask
# Out:
# team1                  team2                        winner
# Kings XI Punjab        Kolkata Knight Riders        Kolkata Knight Riders          11
# Kolkata Knight Riders  Mumbai Indians               Mumbai Indians                 10
#                        Royal Challengers Bangalore  Royal Challengers Bangalore     9
# Mumbai Indians         Delhi Daredevils             Mumbai Indians                  9
# Delhi Daredevils       Kings XI Punjab              Kings XI Punjab                 8
#                                                                                    ..
# Mumbai Indians         Rising Pune Supergiant       Rising Pune Supergiant          1
#                                                     Mumbai Indians                  1
# Deccan Chargers        Chennai Super Kings          Chennai Super Kings             1
#                                                     Deccan Chargers                 1
# ...

# %% [markdown]
# # plots

# %%
import matplotlib.pyplot as py

# %%
data['winner'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
data['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='toss_decision'>

# %%
data['win_by_runs'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # series is bulding block to DataFrame

# %%
myseries=data['winner'].value_counts()
myseries
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
import pandas as pd

# %%
data['team2'].value_counts()
# Out:
# Delhi Daredevils               84
# Royal Challengers Bangalore    82
# Kolkata Knight Riders          80
# Mumbai Indians                 75
# Kings XI Punjab                71
# Rajasthan Royals               64
# Chennai Super Kings            54
# Deccan Chargers                32
# Sunrisers Hyderabad            30
# Pune Warriors                  26
# Gujarat Lions                  16
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: team2, dtype: int64

# %%
data['team2'].value_counts()+data['team1'].value_counts().sort_values(ascending=False)
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# dtype: int64

# %%
data['team2'].value_counts()+data['team1'].value_counts().tail(2).sort_values()
# Out:
# Chennai Super Kings             NaN
# Deccan Chargers                 NaN
# Delhi Daredevils                NaN
# Gujarat Lions                   NaN
# Kings XI Punjab                 NaN
# Kochi Tuskers Kerala           14.0
# Kolkata Knight Riders           NaN
# Mumbai Indians                  NaN
# Pune Warriors                   NaN
# Rajasthan Royals                NaN
# Rising Pune Supergiant          NaN
# Rising Pune Supergiants        14.0
# Royal Challengers Bangalore     NaN
# Sunrisers Hyderabad             NaN
# dtype: float64

# %% [markdown]
# # inplace=True..................... for making permanent changes

# %%
data.sort_values(['city','date'],ascending=[True,False])           #city ascending, date descending
# Out:
#     id  season       city        date                   team1  \
# 58  59    2017  Hyderabad  2017-05-21          Mumbai Indians
# 57  58    2017  Hyderabad  2017-05-19   Kolkata Knight Riders
# 56  57    2017  Hyderabad  2017-05-17     Sunrisers Hyderabad
# 55  56    2017  Hyderabad  2017-05-16  Rising Pune Supergiant
# 53  54    2017  Hyderabad  2017-05-14         Kings XI Punjab
# ..  ..     ...        ...         ...                     ...
# 62  63    2008  Hyderabad  2008-04-20          Mumbai Indians
# 63  64    2008  Hyderabad  2008-04-20         Deccan Chargers
# 60  61    2008  Hyderabad  2008-04-19     Chennai Super Kings
# 61  62    2008  Hyderabad  2008-04-19        Rajasthan Royals
# 59  60    2008  Hyderabad  2008-04-18   Kolkata Knight Riders
#
#                           team2                  toss_winner toss_decision  \
# 58       Rising Pune Supergiant               Mumbai Indians           bat
# ...

# %%
#removing duplicates

# %%
data.drop_duplicates(subset=['city']).shape
# Out:
# (1, 18)

# %%
data.drop_duplicates('season').shape                        #per season, per match
# Out:
# (10, 18)

# %%
data.drop_duplicates('season',keep='last')                 #last match of season/final match
# Out:
#       id  season       city        date                team1  \
# 58    59    2017  Hyderabad  2017-05-21       Mumbai Indians
# 116  117    2008  Hyderabad  2008-06-01  Chennai Super Kings
# 173  174    2009  Hyderabad  2009-05-24      Deccan Chargers
# 233  234    2010  Hyderabad  2010-04-25  Chennai Super Kings
# 306  307    2011  Hyderabad  2011-05-28  Chennai Super Kings
# 380  381    2012  Hyderabad  2012-05-27  Chennai Super Kings
# 456  457    2013  Hyderabad  2013-05-26       Mumbai Indians
# 516  517    2014  Hyderabad  2014-06-01      Kings XI Punjab
# 575  576    2015  Hyderabad  2015-05-24       Mumbai Indians
# 635  636    2016  Hyderabad  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 58        Rising Pune Supergiant               Mumbai Indians           bat
# 116             Rajasthan Royals             Rajasthan Royals         field
# ...

# %%
# First season of the match

data.drop_duplicates('season',keep='first')[['season','winner']].sort_values('season',ascending=False)               

#first match of season/first match
# Out:
#      season                   winner
# 0      2017      Sunrisers Hyderabad
# 576    2016  Rising Pune Supergiants
# 517    2015    Kolkata Knight Riders
# 457    2014    Kolkata Knight Riders
# 381    2013    Kolkata Knight Riders
# 307    2012           Mumbai Indians
# 234    2011      Chennai Super Kings
# 174    2010    Kolkata Knight Riders
# 117    2009           Mumbai Indians
# 59     2008    Kolkata Knight Riders

# %%
# Last season of the match

data.drop_duplicates('season',keep='last')[['season','winner']].sort_values('season',ascending=True)               #last match of season/last match
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians

# %% [markdown]
# # the groupby()

# %%
len('Rajasthan Royals')
# Out:
# 16

# %%
len('runs')
# Out:
# 4

# %% [markdown]
# # Pivot table

# %%
mask=data['win_by_wickets']==6
six=data[mask]
six.shape
# Out:
# (68, 18)

# %%
six.pivot_table(index='winner',columns='season',values='win_by_runs',aggfunc='count')
# Out:
# season                       2008  2009  2010  2011  2012  2013  2014  2015  \
# winner
# Chennai Super Kings           NaN   NaN   1.0   1.0   NaN   NaN   NaN   1.0
# Deccan Chargers               NaN   3.0   1.0   1.0   NaN   NaN   NaN   NaN
# Delhi Daredevils              NaN   2.0   2.0   NaN   2.0   NaN   1.0   1.0
# Gujarat Lions                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Kings XI Punjab               2.0   2.0   1.0   2.0   2.0   1.0   2.0   NaN
# Kolkata Knight Riders         NaN   NaN   NaN   NaN   1.0   2.0   1.0   1.0
# Mumbai Indians                NaN   NaN   NaN   NaN   NaN   NaN   NaN   1.0
# Pune Warriors                 NaN   NaN   NaN   1.0   NaN   NaN   NaN   NaN
# Rajasthan Royals              2.0   NaN   NaN   2.0   NaN   1.0   1.0   1.0
# Rising Pune Supergiant        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Royal Challengers Bangalore   NaN   2.0   1.0   1.0   1.0   NaN   NaN   1.0
# ...

# %%
import seaborn as sns
sns.heatmap(pt)
# Out:
# <AxesSubplot:xlabel='season', ylabel='winner'>

# %%
data.corr()          
#numerical values in rows and colums and resultant will be 1, negative corr means inversely proportional, id++,win by runs--
# Out:
#                       id    season  dl_applied  win_by_runs  win_by_wickets  \
# id              1.000000  0.471087    0.024281    -0.010263       -0.015510
# season          0.471087  1.000000    0.004170    -0.016815       -0.000708
# dl_applied      0.024281  0.004170    1.000000    -0.010893       -0.011640
# win_by_runs    -0.010263 -0.016815   -0.010893     1.000000       -0.565181
# win_by_wickets -0.015510 -0.000708   -0.011640    -0.565181        1.000000
# umpire3              NaN       NaN         NaN          NaN             NaN
#
#                 umpire3
# id                  NaN
# season              NaN
# dl_applied          NaN
# win_by_runs         NaN
# win_by_wickets      NaN
# umpire3             NaN

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
# Rename -shift + tab ------renaming city & Date Of Month

data.rename(columns={'city':'place','date':'DOM'})
# Out:
#      level_0  index  season      place         DOM  \
# id
# 1          0      0    2017  Hyderabad  2017-04-05
# 2          1      1    2017       Pune  2017-04-06
# 3          2      2    2017     Rajkot  2017-04-07
# 4          3      3    2017     Indore  2017-04-08
# 5          4      4    2017  Bangalore  2017-04-08
# ..       ...    ...     ...        ...         ...
# 632      631    631    2016     Raipur  2016-05-22
# 633      632    632    2016  Bangalore  2016-05-24
# 634      633    633    2016      Delhi  2016-05-25
# 635      634    634    2016      Delhi  2016-05-27
# 636      635    635    2016  Bangalore  2016-05-29
#
#                            team1                        team2  \
# id
# 1            Sunrisers Hyderabad  Royal Challengers Bangalore
# 2                 Mumbai Indians       Rising Pune Supergiant
# 3                  Gujarat Lions        Kolkata Knight Riders
# 4         Rising Pune Supergiant              Kings XI Punjab
# ...

# %%
data.head(10)
# Out:
#     level_0  index  season       city        date  \
# id
# 1         0      0    2017  Hyderabad  2017-04-05
# 2         1      1    2017       Pune  2017-04-06
# 3         2      2    2017     Rajkot  2017-04-07
# 4         3      3    2017     Indore  2017-04-08
# 5         4      4    2017  Bangalore  2017-04-08
# 6         5      5    2017  Hyderabad  2017-04-09
# 7         6      6    2017     Mumbai  2017-04-09
# 8         7      7    2017     Indore  2017-04-10
# 9         8      8    2017       Pune  2017-04-11
# 10        9      9    2017     Mumbai  2017-04-12
#
#                           team1                        team2  \
# id
# 1           Sunrisers Hyderabad  Royal Challengers Bangalore
# 2                Mumbai Indians       Rising Pune Supergiant
# 3                 Gujarat Lions        Kolkata Knight Riders
# 4        Rising Pune Supergiant              Kings XI Punjab
# 5   Royal Challengers Bangalore             Delhi Daredevils
# ...

# %%
# set index() & reset index() -                  use set_index(id)

# %%
data.reset_index('id')                            #index as id
# Out:
#       id  level_0  index  season       city        date  \
# 0      1        0      0    2017  Hyderabad  2017-04-05
# 1      2        1      1    2017       Pune  2017-04-06
# 2      3        2      2    2017     Rajkot  2017-04-07
# 3      4        3      3    2017     Indore  2017-04-08
# 4      5        4      4    2017  Bangalore  2017-04-08
# ..   ...      ...    ...     ...        ...         ...
# 631  632      631    631    2016     Raipur  2016-05-22
# 632  633      632    632    2016  Bangalore  2016-05-24
# 633  634      633    633    2016      Delhi  2016-05-25
# 634  635      634    634    2016      Delhi  2016-05-27
# 635  636      635    635    2016  Bangalore  2016-05-29
#
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# ...

# %%
data['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
data['winner'].value_counts().reset_index()                #reset will convert into data frame
# Out:
#                           index  winner
# 0                Mumbai Indians      92
# 1           Chennai Super Kings      79
# 2         Kolkata Knight Riders      77
# 3   Royal Challengers Bangalore      73
# 4               Kings XI Punjab      70
# 5              Rajasthan Royals      63
# 6              Delhi Daredevils      62
# 7           Sunrisers Hyderabad      42
# 8               Deccan Chargers      29
# 9                 Gujarat Lions      13
# 10                Pune Warriors      12
# 11       Rising Pune Supergiant      10
# 12         Kochi Tuskers Kerala       6
# 13      Rising Pune Supergiants       5

# %% [markdown]
# # Dropna() -----missing values________Dropping missing data

# %%
data.shape
# Out:
# (636, 19)

# %%
data.dropna().shape
# Out:
# (0, 19)

# %%
data.dropna(how='all').shape             #no such value where all data is missing
# Out:
# (636, 19)

# %%
data.dropna(axis=1,how='all').shape       #delete evry column where missing values-o/p- 6 values missing
# Out:
# (636, 18)

# %%
data.dropna(subset=['umpire1','umpire3']).shape         #remove null values from umpire1,3
# Out:
# (0, 19)

# %% [markdown]
# # fillna() ----------filling missing valies____________

# %%
data['umpire1'].fillna("not specified",inplace=True)
data
# Out:
#      level_0  index  season       city        date  \
# id
# 1          0      0    2017  Hyderabad  2017-04-05
# 2          1      1    2017       Pune  2017-04-06
# 3          2      2    2017     Rajkot  2017-04-07
# 4          3      3    2017     Indore  2017-04-08
# 5          4      4    2017  Bangalore  2017-04-08
# ..       ...    ...     ...        ...         ...
# 632      631    631    2016     Raipur  2016-05-22
# 633      632    632    2016  Bangalore  2016-05-24
# 634      633    633    2016      Delhi  2016-05-25
# 635      634    634    2016      Delhi  2016-05-27
# 636      635    635    2016  Bangalore  2016-05-29
#
#                            team1                        team2  \
# id
# 1            Sunrisers Hyderabad  Royal Challengers Bangalore
# 2                 Mumbai Indians       Rising Pune Supergiant
# 3                  Gujarat Lions        Kolkata Knight Riders
# 4         Rising Pune Supergiant              Kings XI Punjab
# ...

# %%
data["umpire3"].fillna('4')
# Out:
# id
# 1      4
# 2      4
# 3      4
# 4      4
# 5      4
#       ..
# 632    4
# 633    4
# 634    4
# 635    4
# 636    4
# Name: umpire3, Length: 636, dtype: object

# %%
data['umpire3'].fillna(method='bfill')             #ffill here will be used for forward fill and bfill for backward fill
# Out:
# id
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
#        ..
# 632   NaN
# 633   NaN
# 634   NaN
# 635   NaN
# 636   NaN
# Name: umpire3, Length: 636, dtype: float64

# %% [markdown]
# # % matplotlibs

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # pie-chart

# %% [markdown]
# ###pie chart

# %%
areas=['marketing','sales','development','hr','customer support']
budget=[2.5,4,4,4.6,6.5]           # main

# %%
plt.pie(budget,labels=areas,autopct="%0.1f%%")           #for percentile
plt.show()             #to remove textual data

# %%
x=[23,45,67,22,11,56]
y=[88,98,67,33,23,45]
plt.scatter(x,y)

# %%
Age=[2,5,8,7,3]
Salary=[22000,25000,28000,23500,20000]

plt.xlabel('Age')
plt.xlabel('Salary')
plt.title('Age vs Salary Graph')
# Out:
# Text(0.5, 1.0, 'Age vs Salary Graph')

# %%
product_id=[1,2,3,4,5,6,7,8]
online_price=[233,456,770,120,222,444,200,300]
plt.plot(product_id,color='red',marker='D')
plt.plot(online_price,color='yellow',markersize=10,marker='+',label='product_id')
plt.plot(product_id,online_price,color='red',marker='+',label='online_prices')
plt.legend()                #label will only work if 'legend()' will be called
plt.ylabel("Products")
plt.xlabel("Prices")
plt.title("Products price comparision")
#
# Out:
# Text(0.5, 1.0, 'Products price comparision')

# %%
# Bar graph

year=[2012,2013,2014,2015,2016,2017,2018]
price=[65000,55000,45000,89000,67000,34000,23000]
plt.bar(year,price,color='green',label="Price")
plt.legend()                                                     #label working because of legend
plt.xlabel("year")
plt.ylabel("price")
plt.title("Year by Year Price Comparison")
plt.show()                                                       #remove text

# %% [markdown]
# # plotly
